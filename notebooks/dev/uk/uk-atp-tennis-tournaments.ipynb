# %%
from tennis_data_pipeline.loader.uk import load_clean_uk_atp_year
from tennis_data_pipeline.handler.uk.cleaner.tournaments import build_uk_tournament_table

df = load_clean_uk_atp_year(2023)
result = build_uk_tournament_table(df)
tournaments, inconsistencies = result.tournaments, result.inconsistencies

display(list(tournaments.columns))
# Out:
# ['tour',
#  'year',
#  'uk_tournament_id',
#  'location',
#  'tournament_name',
#  'series',
#  'surface',
#  'best_of',
#  'is_outdoor',
#  'start_date',
#  'end_date',
#  'num_matches',
#  'num_rounds',
#  'num_awarded_matches',
#  'num_completed_matches',
#  'num_retired_matches',
#  'num_walkover_matches',
#  'num_players',
#  'champion',
#  'runner_up',
#  'champion_avg_rank',
#  'champion_avg_odds']

# %%
inconsistencies
# Out:
# Empty DataFrame
# Columns: [tournament_name, series, surface, best_of, is_outdoor]
# Index: []

# %%
tournaments
# Out:
#    tour  year  uk_tournament_id   location           tournament_name  \
# 0   atp  2023                 1   Adelaide  Adelaide International 1
# 1   atp  2023                 2       Pune          Maharashtra Open
# 2   atp  2023                 3   Adelaide  Adelaide International 2
# 3   atp  2023                 4   Auckland               ASB Classic
# 4   atp  2023                 5  Melbourne           Australian Open
# ..  ...   ...               ...        ...                       ...
# 60  atp  2023                60     Vienna               Vienna Open
# 61  atp  2023                61      Paris       BNP Paribas Masters
# 62  atp  2023                62       Metz           Open de Moselle
# 63  atp  2023                63      Sofia                Sofia Open
# 64  atp  2023                64      Turin               Masters Cup
#
#           series surface  best_of  is_outdoor start_date  ... num_rounds  \
# ...

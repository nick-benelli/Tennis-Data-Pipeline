# %%
from pathlib import Path
import pandas as pd

# %%
YEAR = 2023
PROJECT_DIR = Path("../..").resolve()
print("Base Directory:", PROJECT_DIR)
# Out:
# Base Directory: /Users/nicholasbenelli/Workspace/repos/GitHub/-sports/-tennis/Tennis-Data-Pipeline

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Tennis Data UK

# %%
df_uk = pd.read_csv(f"../../data/clean/tennis-data-uk/atp/atp_singles_results_{YEAR}.csv")
print(list(df_uk.columns))

df_uk.head()
# Out:
# ['ATP', 'Year', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment', 'B365W', 'B365L', 'PSW', 'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL']
#    ATP  Year  Location                Tournament    Date  Series    Court  \
# 0    1  2023  Adelaide  Adelaide International 1  1/1/23  ATP250  Outdoor
# 1    1  2023  Adelaide  Adelaide International 1  1/1/23  ATP250  Outdoor
# 2    1  2023  Adelaide  Adelaide International 1  1/2/23  ATP250  Outdoor
# 3    1  2023  Adelaide  Adelaide International 1  1/2/23  ATP250  Outdoor
# 4    1  2023  Adelaide  Adelaide International 1  1/2/23  ATP250  Outdoor
#
#   Surface      Round  Best of  ... Lsets    Comment  B365W  B365L   PSW   PSL  \
# 0    Hard  1st Round        3  ...   1.0  Completed   1.91   1.91  1.93  1.95
# 1    Hard  1st Round        3  ...   0.0    Retired   1.36   3.20  1.39  3.25
# 2    Hard  1st Round        3  ...   0.0  Completed   1.57   2.38  1.58  2.53
# 3    Hard  1st Round        3  ...   1.0  Completed   3.75   1.29  4.00  1.28
# 4    Hard  1st Round        3  ...   0.0  Completed   6.50   1.11  6.20  1.15
#
#    MaxW  MaxL  AvgW  AvgL
# 0  1.99  1.95  1.89  1.89
# 1  1.44  3.40  1.36  3.12
# 2  1.64  2.53  1.58  2.36
# 3  4.00  1.31  3.56  1.29
# 4  6.75  1.18  6.04  1.13
#
# [5 rows x 37 columns]

# %%
KEY_COLUMNS = ["ATP", "Year", "Location"]
INFO_COLS =  ["Tournament", "Series", "Court", "Surface", "Best of"]

# %% [markdown]
# Get Tournaments and their information

# %%
from tennis_data_pipeline.validatation.tennis_data_uk.tournaments import (
    find_uk_inconsistent_tournaments, 
    find_uk_reused_tournament_ids, 
)

# %%
inconsistent_tourneys = find_uk_inconsistent_tournaments(df_uk, key_columns=KEY_COLUMNS, info_cols=INFO_COLS)
inconsistent_tourneys
# Out:
# All tournament attributes are consistent.
# (Empty DataFrame
#  Columns: [Tournament, Series, Court, Surface, Best of]
#  Index: [],
#  Empty DataFrame
#  Columns: [ATP, Year, Location, Tournament, Date, Series, Court, Surface, Round, Best of, Winner, Loser, WRank, LRank, WPts, LPts, W1, L1, W2, L2, W3, L3, W4, L4, W5, L5, Wsets, Lsets, Comment, B365W, B365L, PSW, PSL, MaxW, MaxL, AvgW, AvgL]
#  Index: []
#
#  [0 rows x 37 columns])

# %%
reused_tourney_id = find_uk_reused_tournament_ids(df=df_uk, id_col= "ATP", disambiguating_cols=["Location", "Tournament"])
reused_tourney_id
# Out:
# Warning: 1 ATP id(s) are reused across different tournaments:
# (     Location  Tournament
#  ATP
#  58          2           2,
#      ATP  Year   Location                       Tournament      Date  Series  \
#  0    58  2023  Stockholm                      Nordic Open  10/16/23  ATP250
#  1    58  2023  Stockholm                      Nordic Open  10/16/23  ATP250
#  31   1.73   2.09  1.82   2.20  1.83  2.02  1.77
#  32   4.33   1.24  4.53   1.25  4.85  1.22  4.24
#  33   2.00   1.87  2.02   1.87  2.12  1.80  2.01
#  34   2.75   1.45  2.94   1.54  2.94  1.45  2.75
#  35   1.40   3.60  1.33   3.60  1.42  3.13  1.36
#  36   2.63   1.43  3.02   1.50  3.02  1.44  2.76
#  37   1.62   2.44  1.61   2.44  1.70  2.28  1.62
#  38   3.50   1.42  3.08   1.42  3.50  1.36  3.11
#  39   1.30   3.81  1.30   3.81  1.31  3.51  1.30
#  40   2.63   1.44  2.99   1.52  3.02  1.45  2.72
#  41   1.44   2.67  1.53   2.80  1.54  2.63  1.48
#  42   1.53   2.86  1.47   2.90  1.56  2.60  1.49
#  43   3.00   1.40  3.22   1.40  3.26  1.37  3.07
#  44   2.75   1.43  3.07   1.56  3.07  1.44  2.76
#  45   1.40   3.18  1.41   3.18  1.45  2.95  1.39
#  46   2.20   1.75  2.21   1.75  2.23  1.69  2.14
#  47   2.38   1.64  2.41   1.64  2.45  1.59  2.34
#  48   3.75   1.27  4.18   1.32  4.18  1.27  3.72
#  49   1.07  11.20  1.07  11.20  1.09  8.51  1.07
#  50   1.91   1.92  1.99   2.09  1.99  1.89  1.90
#  51   1.57   2.39  1.65   2.52  1.73  2.27  1.62
#  52   1.57   2.47  1.61   2.47  1.68  2.31  1.60
#  53   1.50   2.91  1.47   2.91  1.51  2.67  1.47
#  54   1.33   3.64  1.33   3.75  1.40  3.36  1.32
#  55   2.63   1.56  2.61   1.58  2.72  1.53  2.52
#  56   4.00   1.27  4.26   1.32  4.26  1.25  3.93
#  57   2.00   1.83  2.08   1.91  2.12  1.81  1.99
#
#  [58 rows x 37 columns])

# %%
import re


def slugify(value: str) -> str:
    value = value.strip().lower()
    value = re.sub(r"[^a-z0-9]+", "_", value)
    return value.strip("_")


def add_source_event_key(df):
    df = df.copy()

    # Date format drifts across seasons (e.g. "1/1/23" vs. "2023-01-01").
    df["Date"] = pd.to_datetime(df["Date"], format="mixed", errors="coerce")
    df["Year"] = df["Date"].dt.year

    df["source_event_key"] = (
        df["Year"].astype(str)
        + "_"
        + df["ATP"].astype(str)
        + "_"
        + df["Location"].map(slugify)
        + "_"
        + df["Tournament"].map(slugify)
    )

    return df

# %%
add_source_event_key(df_uk)
# Out:
#       ATP  Year  Location                Tournament       Date       Series  \
# 0       1  2023  Adelaide  Adelaide International 1 2023-01-01       ATP250
# 1       1  2023  Adelaide  Adelaide International 1 2023-01-01       ATP250
# 2       1  2023  Adelaide  Adelaide International 1 2023-01-02       ATP250
# 3       1  2023  Adelaide  Adelaide International 1 2023-01-02       ATP250
# 4       1  2023  Adelaide  Adelaide International 1 2023-01-02       ATP250
# ...   ...   ...       ...                       ...        ...          ...
# 2698   64  2023     Turin               Masters Cup 2023-11-17  Masters Cup
# 2699   64  2023     Turin               Masters Cup 2023-11-17  Masters Cup
# 2700   64  2023     Turin               Masters Cup 2023-11-18  Masters Cup
# 2701   64  2023     Turin               Masters Cup 2023-11-18  Masters Cup
# 2702   64  2023     Turin               Masters Cup 2023-11-19  Masters Cup
#
#         Court Surface        Round  Best of  ...    Comment B365W  B365L  \
# 0     Outdoor    Hard    1st Round        3  ...  Completed  1.91   1.91
# 1     Outdoor    Hard    1st Round        3  ...    Retired  1.36   3.20
# 2     Outdoor    Hard    1st Round        3  ...  Completed  1.57   2.38
# 3     Outdoor    Hard    1st Round        3  ...  Completed  3.75   1.29
# 4     Outdoor    Hard    1st Round        3  ...  Completed  6.50   1.11
# ...       ...     ...          ...      ...  ...        ...   ...    ...
# 2698   Indoor    Hard  Round Robin        3  ...  Completed  1.67   2.20
# 2699   Indoor    Hard  Round Robin        3  ...  Completed  1.62   2.30
# 2700   Indoor    Hard   Semifinals        3  ...  Completed  1.67   2.20
# 2701   Indoor    Hard   Semifinals        3  ...  Completed  1.62   2.30
# 2702   Indoor    Hard    The Final        3  ...  Completed  1.53   2.50
#
#        PSW   PSL  MaxW  MaxL  AvgW  AvgL  \
# 0     1.93  1.95  1.99  1.95  1.89  1.89
# 1     1.39  3.25  1.44  3.40  1.36  3.12
# 2     1.58  2.53  1.64  2.53  1.58  2.36
# 3     4.00  1.28  4.00  1.31  3.56  1.29
# 4     6.20  1.15  6.75  1.18  6.04  1.13
# ...    ...   ...   ...   ...   ...   ...
# 2698  1.78  2.16  1.78  2.30  1.68  2.19
# 2699  1.74  2.23  1.76  2.35  1.66  2.22
# 2700  1.69  2.31  1.71  2.36  1.64  2.26
# 2701  1.67  2.36  1.70  2.43  1.63  2.28
# 2702  1.62  2.45  1.62  2.68  1.55  2.48
#
#                               source_event_key
# 0     2023_1_adelaide_adelaide_international_1
# 1     2023_1_adelaide_adelaide_international_1
# 2     2023_1_adelaide_adelaide_international_1
# 3     2023_1_adelaide_adelaide_international_1
# 4     2023_1_adelaide_adelaide_international_1
# ...                                        ...
# 2698                 2023_64_turin_masters_cup
# 2699                 2023_64_turin_masters_cup
# 2700                 2023_64_turin_masters_cup
# 2701                 2023_64_turin_masters_cup
# 2702                 2023_64_turin_masters_cup
#
# [2703 rows x 38 columns]

# %%
add_source_event_key(df_uk)

# %%
display(
    df_uk.loc[
        df_uk["ATP"].isin([38]),
        ["ATP", "Location", "Tournament", "Series", "Court", "Surface", "Best of", "Date"],
    ].drop_duplicates()
)

# %%
uk_tourneys = df_uk['Tournament'].unique()
print(uk_tourneys)

# %%
df_timl.loc[~df_timl['tourney_name'].str.contains("Davis Cup"), "tourney_name"].unique()

# %%
source_df = df_uk.copy()
canonical_df = df_timl.loc[~df_timl['tourney_name'].str.contains("Davis Cup")].copy()


source_tournaments = (
    source_df[["Tournament"]]
    .drop_duplicates()
    .rename(columns={"Tournament": "source_tournament_name"})
)

canonical_tournaments = (
    canonical_df[["tourney_id", "tourney_name"]]
    .drop_duplicates()
    .rename(
        columns={
            "tourney_id": "canonical_tournament_id",
            "tourney_name": "canonical_tournament_name",
        }
    )
)

tournament_crosswalk = source_tournaments.merge(
    canonical_tournaments,
    left_on="source_tournament_name",
    right_on="canonical_tournament_name",
    how="left",
    validate="one_to_one",
)

tournament_crosswalk["match_method"] = "exact_name"
tournament_crosswalk["confidence"] = 1.0
tournament_crosswalk["review_flag"] = (
    tournament_crosswalk["canonical_tournament_id"].isna()
)

# %%
tournament_crosswalk

# %%
tournament_crosswalk["year"] = 2023
tournament_crosswalk["source"] = "tennis_data_uk"

# %%
print(tournament_crosswalk)
